# %% [markdown]
# # 01 · EDA & Baseline Model (Customer Churn)

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv(Path('../data/raw/churn_sample.csv'))
df.head()

# %% [markdown]
# ## Target balance

# %%
df['churn'].value_counts(normalize=True)
